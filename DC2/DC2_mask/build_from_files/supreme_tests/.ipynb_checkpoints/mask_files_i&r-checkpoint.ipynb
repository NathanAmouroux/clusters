# %%
import healsparse as hsp
import healpy as hp
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table

# %%
filename = "/sps/lsst/groups/desc/shared/DC2-prod/Run2.2i/addons/supreme/dr6/supreme_dc2_dr6d_v3_r_coadd_mask_or.hs"
#filename = "/sps/lsst/groups/desc/shared/DC2-prod/Run2.2i/addons/supreme/dr6/supreme_dc2_dr6d_v3_i_nexp_sum.hs"
#filename = "/sps/lsst/groups/desc/shared/DC2-prod/Run2.2i/addons/supreme/dr6/supreme_dc2_dr6d_v3_i_exptime_sum.hs"
#filename = "/sps/lsst/groups/desc/shared/DC2-prod/Run2.2i/addons/supreme/dr6/supreme_dc2_dr6d_v3_r_maglim_aper_wmean.hs"

# %%
mask = hsp.HealSparseMap.read(filename)

# %%
mask
# Out:
# HealSparseMap: nside_coverage = 32, nside_sparse = 32768, int32

# %%
hsp_mask = mask.coverage_mask
hp.mollview(hsp_mask, title='Coverage Mask')

# %%
hsp_cov_map = mask.coverage_map
hp.mollview(hsp_cov_map, title='Coverage Map')

# %%
valid_pixels_indices = mask.valid_pixels
print(valid_pixels_indices)
# Out:
# [8922726253 8922726255 8922726262 ... 9466587809 9466587810 9466587811]

# %%
nside_sparse = mask._nside_sparse
#nside_coverage = mask._nside_coverage

# %%
nside_sparse
# Out:
# 32768

# %%
vpix, ra, dec = mask.valid_pixels_pos(return_pixels=True)

# %%
print(len(vpix))
# Out:
# 94625167

# %%
ra_box = ra[(ra<60.45) * (ra>60.35)]
dec_box = dec[(dec>-36.20) * (dec<-36.10)]

# %%
len(dec_box)
# Out:
# 548810

# %%
val_min = 30000000
val_max = 40000000

# %%
plt.hexbin(ra[val_min:val_max], dec[val_min:val_max], C=mask[vpix[val_min:val_max]], gridsize=200)
plt.colorbar()
#plt.xlim([60.45,60.10])
#plt.ylim([-36.40,-36.10])
plt.show()

# %%
gal = Table.read("/sps/lsst/users/namourou/web/desc/clusters/DC2_mask/galaxies.fits")

# %%
ra_min, ra_max = min(gal['ra']), max(gal['ra'])
dec_min, dec_max = min(gal['dec']), max(gal['dec'])
#ra_min, ra_max = 60,60.5
#dec_min, dec_max = -36.4, -36

# Définir la taille des carrés (en degrés)
cote_carré = 0.01  # Vous pouvez ajuster cette valeur

# Créer une grille de carrés
ra_bins = np.arange(ra_min, ra_max, cote_carré)
dec_bins = np.arange(dec_min, dec_max, cote_carré)

# Créer des tableaux pour stocker les densités de galaxies
densités = np.zeros((len(ra_bins) - 1, len(dec_bins) - 1), dtype=float)

# %%
dens = np.histogram2d(gal['ra'], gal['dec'], bins = (ra_bins,dec_bins))[0]

# %%
ra_pt = []
for i in range(len(ra_bins)-1):
    ra_pt.append((ra_bins[i]+ra_bins[i+1])/2) 
dec_pt = []
for i in range(len(dec_bins)-1):
    dec_pt.append((dec_bins[i]+dec_bins[i+1])/2)

# %%
ra_pt_grid, dec_pt_grid = np.meshgrid(ra_pt, dec_pt)

# %%
mu = np.mean(dens)
sigma = np.std(dens)
print(mu,sigma)
indices_inférieurs_à_la_moyenne = np.where(dens.T < mu-2*sigma)
# Maintenant, extrayez les valeurs de RA et Dec correspondant aux indices inférieurs à la moyenne
ra_mask = ra_pt_grid[indices_inférieurs_à_la_moyenne]
dec_mask = dec_pt_grid[indices_inférieurs_à_la_moyenne]
# Out:
# 20.164092664092664 5.078675311285442

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.hexbin(ra[val_min:val_max], dec[val_min:val_max], C=mask[vpix[val_min:val_max]], gridsize = 300)
plt.colorbar()
plt.scatter(gal['ra'],gal['dec'], s=0.5, alpha = .5, color = 'red')
#plt.scatter(ra_mask, dec_mask, s=5, color = 'white')
#plt.scatter(max(ra_bins),max(dec_bins), color = 'black' )
plt.xlabel("ra")
plt.ylabel("dec")
plt.title('galaxies in tract')
#plt.xlim([60,60.5])
#plt.ylim([-36.4,-36])
for i in range(len(ra_mask)):
    rectangle = plt.Rectangle((ra_mask[i]-0.5*cote_carré, dec_mask[i]-0.5*cote_carré), cote_carré, cote_carré, fill=True, color='black', alpha = .5)
    ax.add_patch(rectangle)
plt.xlim([60.45,60.1])
plt.ylim([-36.35,-36.10])
#plt.legend()
# Out:
# (-36.35, -36.1)

# %%
#gal_all = Table.read("/sps/lsst/users/namourou/web/desc/clusters/DC2_mask/galaxies_nocut.fits")

# %%
#gal_nextd = gal_all[(gal_all['extend']!=0.0)*(gal_all['extend']!=1.0)]

# %%
fig, ax = plt.subplots(figsize=(10,6))
#plt.hexbin(ra[val_min:val_max], dec[val_min:val_max], C=mask[vpix[val_min:val_max]], gridsize = 2500, vmin=24.9, vmax=25.1)
plt.scatter(ra[val_min:val_max], dec[val_min:val_max], c=mask[vpix[val_min:val_max]], vmin=24.9, vmax=25.1)
plt.colorbar()
#plt.scatter(gal_nextd['ra'],gal_nextd['dec'], s=1, alpha = 1, color = 'red')
#plt.scatter(ra_mask, dec_mask, s=5, color = 'white')
#plt.scatter(max(ra_bins),max(dec_bins), color = 'black' )
plt.xlabel("ra")
plt.ylabel("dec")
plt.title('galaxies in tract')
#plt.xlim([60,60.5])
#plt.ylim([-36.4,-36])
for i in range(len(ra_mask)):
    rectangle = plt.Rectangle((ra_mask[i]-0.5*cote_carré, dec_mask[i]-0.5*cote_carré), cote_carré, cote_carré, fill=True, color='black', alpha = .1)
    ax.add_patch(rectangle)
plt.xlim([60.45,60.1])
plt.ylim([-36.35,-36.10])
#plt.legend()
# Out:
# (-36.35, -36.1)

# %%
plt.hist(mask[vpix[val_min:val_max]], bins = np.linspace(0,60000, 601))#, bins = np.linspace(22.2,26.2,401))
#plt.xlim([37000,40000])
plt.ylim([0,70000])
plt.show()

# %%
n, bins = np.histogram(mask[vpix[val_min:val_max]], bins = np.linspace(0,60000, 601))

# %%
bins
# Out:
# array([    0.,   100.,   200.,   300.,   400.,   500.,   600.,   700.,
#          800.,   900.,  1000.,  1100.,  1200.,  1300.,  1400.,  1500.,
#         1600.,  1700.,  1800.,  1900.,  2000.,  2100.,  2200.,  2300.,
#         2400.,  2500.,  2600.,  2700.,  2800.,  2900.,  3000.,  3100.,
#         3200.,  3300.,  3400.,  3500.,  3600.,  3700.,  3800.,  3900.,
#         4000.,  4100.,  4200.,  4300.,  4400.,  4500.,  4600.,  4700.,
#         4800.,  4900.,  5000.,  5100.,  5200.,  5300.,  5400.,  5500.,
#         5600.,  5700.,  5800.,  5900.,  6000.,  6100.,  6200.,  6300.,
#         6400.,  6500.,  6600.,  6700.,  6800.,  6900.,  7000.,  7100.,
#         7200.,  7300.,  7400.,  7500.,  7600.,  7700.,  7800.,  7900.,
#         8000.,  8100.,  8200.,  8300.,  8400.,  8500.,  8600.,  8700.,
#         8800.,  8900.,  9000.,  9100.,  9200.,  9300.,  9400.,  9500.,
#         9600.,  9700.,  9800.,  9900., 10000., 10100., 10200., 10300.,
#        10400., 10500., 10600., 10700., 10800., 10900., 11000., 11100.,
#        11200., 11300., 11400., 11500., 11600., 11700., 11800., 11900.,
#        12000., 12100., 12200., 12300., 12400., 12500., 12600., 12700.,
#        12800., 12900., 13000., 13100., 13200., 13300., 13400., 13500.,
#        13600., 13700., 13800., 13900., 14000., 14100., 14200., 14300.,
#        14400., 14500., 14600., 14700., 14800., 14900., 15000., 15100.,
#        15200., 15300., 15400., 15500., 15600., 15700., 15800., 15900.,
#        16000., 16100., 16200., 16300., 16400., 16500., 16600., 16700.,
#        16800., 16900., 17000., 17100., 17200., 17300., 17400., 17500.,
#        17600., 17700., 17800., 17900., 18000., 18100., 18200., 18300.,
#        18400., 18500., 18600., 18700., 18800., 18900., 19000., 19100.,
#        19200., 19300., 19400., 19500., 19600., 19700., 19800., 19900.,
#        20000., 20100., 20200., 20300., 20400., 20500., 20600., 20700.,
#        20800., 20900., 21000., 21100., 21200., 21300., 21400., 21500.,
#        21600., 21700., 21800., 21900., 22000., 22100., 22200., 22300.,
#        22400., 22500., 22600., 22700., 22800., 22900., 23000., 23100.,
#        23200., 23300., 23400., 23500., 23600., 23700., 23800., 23900.,
#        24000., 24100., 24200., 24300., 24400., 24500., 24600., 24700.,
#        24800., 24900., 25000., 25100., 25200., 25300., 25400., 25500.,
#        25600., 25700., 25800., 25900., 26000., 26100., 26200., 26300.,
#        26400., 26500., 26600., 26700., 26800., 26900., 27000., 27100.,
#        27200., 27300., 27400., 27500., 27600., 27700., 27800., 27900.,
#        28000., 28100., 28200., 28300., 28400., 28500., 28600., 28700.,
#        28800., 28900., 29000., 29100., 29200., 29300., 29400., 29500.,
#        29600., 29700., 29800., 29900., 30000., 30100., 30200., 30300.,
#        30400., 30500., 30600., 30700., 30800., 30900., 31000., 31100.,
#        31200., 31300., 31400., 31500., 31600., 31700., 31800., 31900.,
#        32000., 32100., 32200., 32300., 32400., 32500., 32600., 32700.,
#        32800., 32900., 33000., 33100., 33200., 33300., 33400., 33500.,
#        33600., 33700., 33800., 33900., 34000., 34100., 34200., 34300.,
#        34400., 34500., 34600., 34700., 34800., 34900., 35000., 35100.,
#        35200., 35300., 35400., 35500., 35600., 35700., 35800., 35900.,
#        36000., 36100., 36200., 36300., 36400., 36500., 36600., 36700.,
#        36800., 36900., 37000., 37100., 37200., 37300., 37400., 37500.,
#        37600., 37700., 37800., 37900., 38000., 38100., 38200., 38300.,
#        38400., 38500., 38600., 38700., 38800., 38900., 39000., 39100.,
#        39200., 39300., 39400., 39500., 39600., 39700., 39800., 39900.,
#        40000., 40100., 40200., 40300., 40400., 40500., 40600., 40700.,
#        40800., 40900., 41000., 41100., 41200., 41300., 41400., 41500.,
#        41600., 41700., 41800., 41900., 42000., 42100., 42200., 42300.,
#        42400., 42500., 42600., 42700., 42800., 42900., 43000., 43100.,
#        43200., 43300., 43400., 43500., 43600., 43700., 43800., 43900.,
#        44000., 44100., 44200., 44300., 44400., 44500., 44600., 44700.,
#        44800., 44900., 45000., 45100., 45200., 45300., 45400., 45500.,
#        45600., 45700., 45800., 45900., 46000., 46100., 46200., 46300.,
#        46400., 46500., 46600., 46700., 46800., 46900., 47000., 47100.,
#        47200., 47300., 47400., 47500., 47600., 47700., 47800., 47900.,
#        48000., 48100., 48200., 48300., 48400., 48500., 48600., 48700.,
#        48800., 48900., 49000., 49100., 49200., 49300., 49400., 49500.,
#        49600., 49700., 49800., 49900., 50000., 50100., 50200., 50300.,
#        50400., 50500., 50600., 50700., 50800., 50900., 51000., 51100.,
#        51200., 51300., 51400., 51500., 51600., 51700., 51800., 51900.,
#        52000., 52100., 52200., 52300., 52400., 52500., 52600., 52700.,
#        52800., 52900., 53000., 53100., 53200., 53300., 53400., 53500.,
#        53600., 53700., 53800., 53900., 54000., 54100., 54200., 54300.,
#        54400., 54500., 54600., 54700., 54800., 54900., 55000., 55100.,
#        55200., 55300., 55400., 55500., 55600., 55700., 55800., 55900.,
#        56000., 56100., 56200., 56300., 56400., 56500., 56600., 56700.,
#        56800., 56900., 57000., 57100., 57200., 57300., 57400., 57500.,
#        57600., 57700., 57800., 57900., 58000., 58100., 58200., 58300.,
#        58400., 58500., 58600., 58700., 58800., 58900., 59000., 59100.,
#        59200., 59300., 59400., 59500., 59600., 59700., 59800., 59900.,
#        60000.])

# %%
len(bins)
# Out:
# 601

# %%
xbins= []
for i in range(len(bins)-1):
    xbins.append((bins[i+1]+bins[i])/2)

# %%
len(xbins)
# Out:
# 600

# %%
n_e = []
for i in range(len(xbins)):
    if n[i]>0:
        n_e.append(xbins[i])

# %%
n[n!=0]
# Out:
# array([ 151087,     135,    1145,    2945,      11, 8867859,  415846,
#           5243,   20195,  533313,     188,    2033])

# %%
n_e
# Out:
# [50.0,
#  5150.0,
#  20450.0,
#  20550.0,
#  21550.0,
#  36850.0,
#  36950.0,
#  37850.0,
#  37950.0,
#  53250.0,
#  54250.0,
#  54350.0]

# %%
sub_mask = mask[vpix[val_min:val_max]]

# %%
cut = 30000
cut1, cut2 = 0, 60000

# %%
c_mag = sub_mask[sub_mask<=cut]
ra_mag = ra[val_min:val_max][sub_mask<=cut]
dec_mag = dec[val_min:val_max][sub_mask<=cut]

# %%
c_mag = sub_mask[(sub_mask>=cut1)*(sub_mask<=cut2)]
ra_mag = ra[val_min:val_max][(sub_mask>=cut1)*(sub_mask<=cut2)]
dec_mag = dec[val_min:val_max][(sub_mask>=cut1)*(sub_mask<=cut2)]

# %%
fig, ax = plt.subplots(figsize=(10,6))
#plt.hexbin(ra[val_min:val_max], dec[val_min:val_max], C=mask[vpix[val_min:val_max]], gridsize = 2500, vmin=24.9, vmax=25.1)
plt.scatter(ra_mag, dec_mag, c=c_mag, s=.5, alpha = .5)
plt.colorbar()
#plt.scatter(gal_nextd['ra'],gal_nextd['dec'], s=1, alpha = 1, color = 'red')
#plt.scatter(ra_mask, dec_mask, s=5, color = 'white')
#plt.scatter(max(ra_bins),max(dec_bins), color = 'black' )
plt.xlabel("ra")
plt.ylabel("dec")
plt.title('masks with magnitude condition')
#plt.xlim([60,60.5])
#plt.ylim([-36.4,-36])
for i in range(len(ra_mask)):
    rectangle = plt.Rectangle((ra_mask[i]-0.5*cote_carré, dec_mask[i]-0.5*cote_carré), cote_carré, cote_carré, fill=True, color='black', alpha = .1)
    ax.add_patch(rectangle)
plt.xlim([60.45,60.1])
plt.ylim([-36.35,-36.10])
#plt.legend()
# Out:
# (-36.35, -36.1)

# %%
len(ra[val_min:val_max])
# Out:
# 10000000

# %%
fig, ax = plt.subplots(figsize=(10,6))


#plt.scatter(gal['ra'],gal['dec'], s=1, alpha = .5, color = 'red')
plt.scatter(ra[val_min:val_max], ra[val_min:val_max], c=sub_mask, s=.5, alpha = .5)
plt.colorbar()
#plt.scatter(ra_mask, dec_mask, s=5, color = 'white')
#plt.scatter(max(ra_bins),max(dec_bins), color = 'black' )
plt.xlabel("ra")
plt.ylabel("dec")
plt.title('galaxies in tract')
#plt.xlim([60,60.5])
#plt.ylim([-36.4,-36])
for i in range(len(ra_mask)):
    rectangle = plt.Rectangle((ra_mask[i]-0.5*cote_carré, dec_mask[i]-0.5*cote_carré), cote_carré, cote_carré, fill=True, color='black', alpha = .5)
    ax.add_patch(rectangle)
#plt.xlim([60.45,60.1])
#plt.ylim([-36.35,-36.10])
#plt.legend()

# %%
len(ra_mag)
# Out:
# 10000000

# %%
len(sub_mask)
# Out:
# 10000000

# %%
sub_mask
# Out:
# array([36896, 36896, 36896, ..., 36896, 36896, 36896], dtype=int32)

# %%
len(ra_box)
# Out:
# 446268

# %%
hsp_map = hsp.HealSparseMap(nside_coverage=nside_sparse, healpix_map=mask)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 hsp_map = hsp.HealSparseMap(nside_coverage=nside_sparse, healpix_map=mask)
#
# File ~/.local/lib/python3.8/site-packages/healsparse-1.6.0-py3.8.egg/healsparse/healSparseMap.py:74, in HealSparseMap.__init__(self, cov_map, cov_index_map, sparse_map, nside_sparse, healpix_map, nside_coverage, primary, sentinel, nest, metadata, _is_view)
#      72     sentinel = hpg.UNSEEN
#      73 if is_integer_value(healpix_map[0]) and not is_integer_value(sentinel):
# ---> 74     raise ValueError("The sentinel must be set to an integer value with an integer healpix_map")
#      75 elif not is_integer_value(healpix_map[0]) and is_integer_value(sentinel):
#      76     raise ValueError("The sentinel must be set to an float value with an float healpix_map")
#
# ValueError: The sentinel must be set to an integer value with an integer healpix_map

# %%
ra_valid, dec_valid = mask.valid_pixels_pos(lonlat=True)
# Let's retrieve the values of the pixels at these locations. There's an alternative way to do this
hsp_map_values = mask.get_values_pos(ra_valid, dec_valid, lonlat=True)

# Another option to retrieve the values of the map can be instead the line below:
#hsp_map_values = hsp_map.get_values_pix(hsp_map.valid_pixels)

size = 1./60*hp.nside2resol(nside_sparse, arcmin=True) # Get the resolution of the pixel
print('Pixel resolution: %.2f deg' % (size))
# Let's take a look, approximating each pixel as Circles with radius = resolution/2
# We will draw circles 10 times larger than they should so we can see them in this map
from matplotlib.patches import Circle
from matplotlib.collections import PatchCollection
# This visualization is not accurate but it helps
patches = [Circle((x_, y_), s_) for x_, y_, s_ in np.broadcast(ra_valid, dec_valid, 10*size/2)]
collection = PatchCollection(patches)
collection.set_array(np.asarray(hsp_map_values))
f, ax = plt.subplots(1,1)
ax.add_collection(collection)
ax.autoscale_view()
plt.sci(collection)
plt.colorbar(label='Pixel values')
plt.xlabel('RA [deg]')
plt.ylabel('Dec [deg]');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ra_valid, dec_valid = mask.valid_pixels_pos(lonlat=True)
#       2 # Let's retrieve the values of the pixels at these locations. There's an alternative way to do this
#       3 hsp_map_values = mask.get_values_pos(ra_valid, dec_valid, lonlat=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'valid_pixels_pos'

# %%
mask.metadata
# Out:
# {'XTENSION': 'BINTABLE',
#  'BITPIX': 8,
#  'NAXIS': 2,
#  'NAXIS1': 8,
#  'NAXIS2': 120,
#  'PCOUNT': 73208653,
#  'GCOUNT': 1,
#  'TFIELDS': 1,
#  'TTYPE1': 'COMPRESSED_DATA',
#  'TFORM1': '1PB(798327)',
#  'ZIMAGE': True,
#  'ZTENSION': 'IMAGE',
#  'ZBITPIX': -64,
#  'ZNAXIS': 1,
#  'ZNAXIS1': 125829120,
#  'ZPCOUNT': 0,
#  'ZGCOUNT': 1,
#  'ZTILE1': 1048576,
#  'ZCMPTYPE': 'GZIP_2',
#  'ZNAME1': 'NOISEBIT',
#  'ZVAL1': 0.0,
#  'ZQUANTIZ': 'NONE',
#  'EXTNAME': 'SPARSE',
#  'PIXTYPE': 'HEALSPARSE',
#  'NSIDE': 32768,
#  'SENTINEL': -1.6375e+30}

# %%
mask.NAXIS2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 mask.NAXIS2
#
# AttributeError: 'HealSparseMap' object has no attribute 'NAXIS2'

# %%
mask.get_values_pos(60.40,-36.15)
# Out:
# 36896

# %%
map_rec = mask[:10]

# %%
map_rec
# Out:
# array([-2147483648, -2147483648, -2147483648, -2147483648, -2147483648,
#        -2147483648, -2147483648, -2147483648, -2147483648, -2147483648],
#       dtype=int32)

# %%
print(map_rec.valid_pixels)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 print(map_rec.valid_pixels)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'valid_pixels'

# %%
# Out:
# {'XTENSION': 'BINTABLE',
#  'BITPIX': 8,
#  'NAXIS': 2,
#  'NAXIS1': 8,
#  'NAXIS2': 120,
#  'PCOUNT': 35858174,
#  'GCOUNT': 1,
#  'TFIELDS': 1,
#  'TTYPE1': 'COMPRESSED_DATA',
#  'TFORM1': '1PB(393580)',
#  'ZIMAGE': True,
#  'ZTENSION': 'IMAGE',
#  'ZBITPIX': 32,
#  'ZNAXIS': 1,
#  'ZNAXIS1': 125829120,
#  'ZPCOUNT': 0,
#  'ZGCOUNT': 1,
#  'ZTILE1': 1048576,
#  'ZCMPTYPE': 'GZIP_2',
#  'EXTNAME': 'SPARSE',
#  'PIXTYPE': 'HEALSPARSE',
#  'NSIDE': 32768,
#  'SENTINEL': -2147483648}

# %%
mask.metadata['NAXIS2']
# Out:
# 120

# %%
print(mask._sparse_map.dtype.fields)
# Out:
# None

# %%
print(exp._sparse_map.dtype.fields)
# Out:
# None

# %%
mask
# Out:
# HealSparseMap: nside_coverage = 32, nside_sparse = 32768, float64

# %%
vpix, ra, dec = mask.valid_pixels_pos(return_pixels=True)
plt.hexbin(ra, dec, C=mask[vpix])
plt.colorbar()
plt.show()

# %%
print(mask.valid_pixels)
# Out:
# [8922726110 8922726111 8922726116 ... 9466587408 9466587409 9466587412]

# %%
ra, dec = mask.valid_pixels_pos(lonlat=True)
print(ra)
print(dec)
# Out:
# [71.40482652 71.40542723 71.40011631 ... 58.78234863 58.78372192
#  58.78509521]
# [-44.63203558 -44.63048821 -44.63667762 ... -26.95874306 -26.95743527
#  -26.95612749]

# %%
len(ra)
# Out:
# 94653318

# %%
len(dec)
# Out:
# 94653318

# %%
len(mask.valid_pixels)
# Out:
# 94653318

# %%
plt.scatter(ra[:100000], dec[:100000], c= mask.valid_pixels[:100000])

# %%
hpmap128 = mask[:10000].generate_healpix_map(nside=128, reduction='mean')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 hpmap128 = mask[:10000].generate_healpix_map(nside=128, reduction='mean')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'generate_healpix_map'
