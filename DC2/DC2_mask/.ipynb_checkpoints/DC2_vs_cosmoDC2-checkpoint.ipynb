# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import healpy as hp
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1101

# %% [markdown]
# ### Full Catalog (tract = 3830)

# %% [markdown]
# ### Catalogs used in AMICO

# %%
gal_cdc2 = Table.read("/sps/lsst/users/tguillem/web/clusters/catalogs/cosmoDC2_photoz_flexzboost/v1/9685/galaxies.fits")
gal_DC2 = Table.read("/sps/lsst/users/namourou/web/desc/clusters/DC2_mask/galaxies.fits")

# %%
plt.figure(figsize=(8,6))
plt.scatter(gal_cdc2['ra'],gal_cdc2['dec'], s=0.1, alpha = .5, label = "cosmoDC2")
plt.scatter(gal_DC2['ra'],gal_DC2['dec'], s=1, alpha = .5, label = "DC2")
plt.xlabel("ra")
plt.ylabel("dec")
plt.title('galaxies in tract')
plt.xlim([60,60.5])
plt.ylim([-36.40,-36.00])
#plt.savefig('copy_hehe.png', bbox_inches='tight')
#plt.legend()
# Out:
# (-36.4, -36.0)

# %%
plt.figure(figsize=(8,6))
plt.scatter(gal_cdc2['ra'],gal_cdc2['dec'], s=1, alpha = .5, label = "cosmoDC2")
plt.scatter(gal_DC2['ra'],gal_DC2['dec'], s=5, alpha = .5, label = "DC2")
plt.xlabel("ra")
plt.ylabel("dec")
plt.title('galaxies in tract')
plt.xlim([60.3,60.5])
plt.ylim([-36.20,-36.10])
#plt.savefig('copy_hehe.png', bbox_inches='tight')
#plt.legend()
# Out:
# (-36.2, -36.1)
