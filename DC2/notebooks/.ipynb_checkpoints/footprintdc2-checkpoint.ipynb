# %%
from astropy.table import Table

# %%
import healpy as hp

# %%
fprt = Table.read("/sps/lsst/users/boutigny/wazp/DC2_test/DC2_test_footprint_cut/8979_footprint.fits")

# %%
fprt = Table.read("/sps/lsst/users/boutigny/wazp/DC2_test/DC2_test_galaxies_cut/8979.fits")

# %%
fprt
# Out:
# <Table length=38285>
#         id                ra         ...       mag_y               zmode
#       int64            float64       ...      float64             float64
# ----------------- ------------------ ... ------------------ -------------------
# 19479519228331378  51.78756477697897 ... 25.853205355813543                0.48
# 19479519228331459   51.7876545986591 ...  24.82449783258114                2.16
# 19479519228331620  51.78426268581005 ...  24.23641355456754                0.61
# 19479519228331666  51.79029138684523 ...   21.9572278877688  1.1300000000000001
# 19479519228331745   51.7876602104737 ... 23.167104133571264 0.47000000000000003
# 19479519228331794  51.79860449540792 ... 24.145238080007285                0.64
# 19479519228331817  51.78931126489152 ... 23.883979419959356                0.38
# 19479519228331865 51.792594751430144 ...  24.05090134244003                0.29
# 19479519228331868  51.78867605439577 ... 26.132659913989354                0.15
# 19479519228331886  51.79021455792473 ... 24.251353432868676                0.98
#               ...                ... ...                ...                 ...
# 20389618503387443 51.572484979722205 ... 21.159665687233165                0.53
# 20389618503387445  51.57329146024827 ...  24.18040274877867                0.28
# 20389618503387446  51.54447057628473 ... 20.275028043218065                0.49
# 20389618503387448  51.56103506424475 ... 21.412583012123065                0.81
# 20389618503387452  51.56100386699998 ... 24.076718335661187                1.32
# 20389618503387460  51.56454651045027 ... 21.899306314403823                1.11
# 20389618503387462 51.564051448647525 ...  24.64450450765478                1.28
# 20389618503387472  51.57166800455296 ... 22.162968657946465  1.3900000000000001
# 20389618503387489  51.57338132197709 ...  21.01026173397907                0.48
# 20389618503387490  51.57201220536934 ... 22.702390399762507                0.81

# %%
nside = 4096

# %%
pix = hp.ang2pix(nside, fprt['ra'], fprt['dec'], nest = False, lonlat = True)

# %%
pix = hp.pix2ang(nside, 9027, nest = False, lonlat = True)

# %%
pix = hp.ang2pix(32, fprt['ra'], fprt['dec'], nest = True, lonlat = True)

# %%
pix
# Out:
# <Column name='dec' dtype='int64' length=1017>
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
#  ...
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979
# 8979

# %%
display(fprt)
# Out:
# <Table length=1017>
#   pixel           ra                dec         signal
#   int64        float64            float64       int64
# --------- ----------------- ------------------- ------
# 152447276 51.59179687499999 -30.963083121794085      1
# 152463659   51.580810546875 -30.973958955308817      1
# 152463660 51.60278320312499 -30.973958955308817      1
# 152480044 51.59179687499999 -30.984836028129322      1
# 152480045    51.61376953125 -30.984836028129322      1
# 152496427   51.580810546875 -30.995714341071547      1
# 152496428 51.60278320312499 -30.995714341071547      1
# 152496429 51.62475585937499 -30.995714341071547      1
# 152512812 51.59179687499999 -31.006593894952005      1
# 152512813    51.61376953125 -31.006593894952005      1
#       ...               ...                 ...    ...
# 153790762     51.5478515625 -31.859090608285456      1
# 153807145   51.536865234375 -31.870070832891926      1
# 153823528       51.50390625  -31.88105236591757      1
# 153823529    51.52587890625  -31.88105236591757      1
# 153839911   51.492919921875 -31.892035208233693      1
# 153839912 51.51489257812499 -31.892035208233693      1
# 153856295 51.48193359374999 -31.903019360712435      1
# 153856296       51.50390625 -31.903019360712435      1
# 153872679   51.492919921875  -31.91400482422665      1
# 153889063 51.48193359374999 -31.924991599649857      1

# %%
fprt_cdt2 = fprt[fprt['signal']!=1]

# %%
fprt_cdt2
# Out:
# <Table length=0>
# pixel    ra     dec   signal
# int64 float64 float64 int64
# ----- ------- ------- ------

# %%
import matplotlib.pyplot as plt

# %%
fprt_cdt = fprt[fprt['signal']==1]

# %%
plt.scatter(fprt['ra'], fprt['dec'])
plt.scatter(fprt_cdt['ra'], fprt_cdt['dec'])

# %%
test =

# %%
from astropy.table import Table, vstack
from astropy.io import fits
import numpy as np
import healpy as hp

import glob
import os

# %%
galDir = "/sps/lsst/users/boutigny/wazp/DC2_test/DC2_test_galaxies_cut/"
footDir = "/sps/lsst/users/boutigny/wazp/DC2_test/DC2_test_footprint_cut/"

# %%
filepath = "/sps/lsst/users/tguillem/web/clusters/catalogs/DC2_photoz_flexzboost/v0/"
tiles = [5074, 5073, 5072, 5071, 5070, 5069, 5068, 5067, 5066, 5065, 4860, 4859, 4858, 4857, 4856, 4855, 4854, 4853, 4852, 4851, 4850, 
         4648, 4647, 4646, 4645, 4644, 4643, 4642, 4641, 4640, 4639, 4638, 4637, 4636, 4441, 4440, 4439, 4438, 4437, 4436, 4435, 4434,
         4433, 4432, 4431, 4430, 4429, 4236, 4235, 4234, 4233, 4232, 4231, 4230, 4229, 4228, 4227, 4226, 4225, 4224, 4035, 4034, 4033, 
         4032, 4031, 4030, 4029, 4028, 4027, 4026, 4025, 4024, 4023, 3837, 3836, 3835, 3834, 3833, 3832, 3831, 3830, 3829, 3828, 3827, 
         3826, 3825, 3643, 3642, 3641, 3640, 3639, 3638, 3637, 3636, 3635, 3634, 3633, 3632, 3631, 3453, 3452, 3451, 3450, 3449, 3448, 
         3447, 3446, 3445, 3444, 3443, 3442, 3441, 3268, 3267, 3266, 3265, 3264, 3263, 3262, 3261, 3260, 3259, 3258, 3257, 3256, 3086, 
         3085, 3084, 3083, 3082, 3081, 3080, 3079, 3078, 3077, 3076, 3075, 3074, 2908, 2907, 2906, 2905, 2904, 2903, 2902, 2901, 2900, 
         2899, 2898, 2897, 2896]

# %%
footDir = "/sps/lsst/groups/clusters/amico_validation_project/catalogs/DC2/footprint/"

# %%
NSIDE = 4096

for tile in tiles:
    bigPix = tile
    print(bigPix)
    galaxies = Table.read(filepath + str(bigPix) + '/galaxies.fits')
    smallPixAll = hp.ang2pix(NSIDE, galaxies["ra"], galaxies["dec"], nest=False, lonlat=True)
    smallPix, indices, counts = np.unique(smallPixAll, return_index=True, return_inverse=False, return_counts=True)
    ra,dec = hp.pix2ang(NSIDE, smallPix, nest=False, lonlat=True)
    pixTable = Table()
    pixTable["pixel"] = smallPix
    pixTable["ra"] = ra
    pixTable["dec"] = dec
    pixTable["signal"] = 1
    footFile = footDir + str(bigPix) + ".fits"
    pixTable.write(footFile, overwrite=True)
    del pixTable, galaxies
# Out:
# 5074
# 5073
# 5072
# 5071
# 5070
# 5069
# 5068
# 5067
# 5066
# 5065
# 4860
# 4859
# 4858
# 4857
# 4856
# 4855
# 4854
# 4853
# 4852
# 4851
# 4850
# 4648
# 4647
# 4646
# 4645
# 4644
# 4643
# 4642
# 4641
# 4640
# 4639
# 4638
# 4637
# 4636
# 4441
# 4440
# 4439
# 4438
# 4437
# 4436
# 4435
# 4434
# 4433
# 4432
# 4431
# 4430
# 4429
# 4236
# 4235
# 4234
# 4233
# 4232
# 4231
# 4230
# 4229
# 4228
# 4227
# 4226
# 4225
# 4224
# 4035
# 4034
# 4033
# 4032
# 4031
# 4030
# 4029
# 4028
# 4027
# 4026
# 4025
# 4024
# 4023
# 3837
# 3836
# 3835
# 3834
# 3833
# 3832
# 3831
# 3830
# 3829
# 3828
# 3827
# 3826
# 3825
# 3643
# 3642
# 3641
# 3640
# 3639
# 3638
# 3637
# 3636
# 3635
# 3634
# 3633
# 3632
# 3631
# 3453
# 3452
# 3451
# 3450
# 3449
# 3448
# 3447
# 3446
# 3445
# 3444
# 3443
# 3442
# 3441
# 3268
# 3267
# 3266
# 3265
# 3264
# 3263
# 3262
# 3261
# 3260
# 3259
# 3258
# 3257
# 3256
# 3086
# 3085
# 3084
# 3083
# 3082
# 3081
# 3080
# 3079
# 3078
# 3077
# 3076
# 3075
# 3074
# 2908
# 2907
# 2906
# 2905
# 2904
# 2903
# 2902
# 2901
# 2900
# 2899
# 2898
# 2897
# 2896

# %%
footFiles = glob.glob(footDir+"*")
footList = []
for f in footFiles:
    pixFits = fits.open(f)
    footList.append(Table(pixFits[1].data))

bigTable = vstack(footList)

# %%
bigTable
# Out:
# <Table length=1519454>
#   pixel           ra                 dec         signal
#   int64        float64             float64       int64
# --------- ------------------ ------------------- ------
# 161491316       53.173828125  -37.18060338169154      1
# 161491318      53.2177734375  -37.18060338169154      1
# 161491319     53.23974609375  -37.18060338169154      1
# 161491320  53.26171874999999  -37.18060338169154      1
# 161491321     53.28369140625  -37.18060338169154      1
# 161491322  53.30566406249999  -37.18060338169154      1
# 161491323     53.32763671875  -37.18060338169154      1
# 161491324  53.34960937499999  -37.18060338169154      1
# 161491325     53.37158203125  -37.18060338169154      1
# 161491327  53.41552734374999  -37.18060338169154      1
#       ...                ...                 ...    ...
# 171351710 49.812709894084215 -44.610371649084954      1
# 171351711 49.835959700335835 -44.610371649084954      1
# 171367190  49.73255813953488 -44.622751245835246      1
# 171367191  49.75581395348837 -44.622751245835246      1
# 171367192 49.779069767441854 -44.622751245835246      1
# 171367193 49.802325581395344 -44.622751245835246      1
# 171367194 49.825581395348834 -44.622751245835246      1
# 171382670 49.745412251227705  -44.63513028347742      1
# 171382671  49.76867407598863  -44.63513028347742      1
# 171382672  49.79193590074955  -44.63513028347742      1

# %%
plt.figure(figsize=(12,12))
_ = plt.scatter(bigTable["ra"], bigTable["dec"], s=0.01)

# %%
intpath = "/sps/lsst/users/tguillem/DESC/desc_april_2022/cluster_challenge/clevar_catalogs/cosmoDC2/m200c_gt_13.0/cosmoDC2_v1.1.4_image/"

# %%
cosmoDC2 = Table.read(intpath + "Catalog.fits")

# %%
cosmoDC2['healpix'] = hp.ang2pix(NSIDE, cosmoDC2["ra"], cosmoDC2["dec"], nest=False, lonlat=True)

# %%
cosmoDC2['mask'] = 0

# %%
cosmoDC2
# Out:
# <Table length=454475>
#       id              ra                 dec         ...  healpix   mask
#     int64          float64             float64       ...   int64   int64
# ------------- ------------------ ------------------- ... --------- -----
#    1600020475 50.775875822529436 -27.112584328955446 ... 146532614     0
#    2700020475 49.466814189348334 -25.960541211222015 ... 144730315     0
#   17200020453  50.16585579512233 -25.259404686564693 ... 143599851     0
#   19000020453  49.51865674267036 -26.131426039026245 ... 144992461     0
#   19800020453 50.691634217578326  -26.88681304144144 ... 146188547     0
#   32800020453  51.49405530538187 -26.309071814426567 ... 145271080     0
#    2000020442  51.03054382968504 -25.767733992572435 ... 144419090     0
#   32300020442  51.48013416475692 -25.825311694587846 ... 144517415     0
#   33300020442 50.315518939516316  -26.69559169836869 ... 145893618     0
#   33400020442  50.63847703474752  -25.19421509701307 ... 143517952     0
#           ...                ...                 ... ...       ...   ...
# 1250600193121  72.16015005667711 -44.629217032676905 ... 171368154     0
# 1618200193121  74.70034657468187  -45.10126887623541 ... 171953660     0
# 1638900193121  72.42018629628721  -43.97819730849899 ... 170557735     0
# 1805500193121  73.16946169058204  -43.91803272264049 ... 170479272     0
# 2529600193121  73.94017550995466  -45.27102452204691 ... 172167844     0
# 3422600193121  74.19531506507741 -45.482217503391844 ... 172426921     0
# 4102700193121   72.6735776786042 -44.728186352433774 ... 171491898     0
# 4540300193121  73.89058920742978  -44.51663276785286 ... 171228736     0
# 5541600193121  72.49711523026612  -44.13615290948399 ... 170745721     0
# 5788500193121  72.49206267522683 -44.091433148096066 ... 170698779     0

# %%
161491324
161491334
161491337
161491338
161491353

# %%
cosmoDC2[cosmoDC2['healpix'] == 161491324]
# Out:
# <Table length=1>
#       id              ra               dec         ...  healpix   mask
#     int64          float64           float64       ...   int64   int64
# ------------- ----------------- ------------------ ... --------- -----
# 1216300124272 53.34653178748154 -37.17510754325196 ... 161491324     1

# %%
per_list = [i for i in range(10,100,10)]
percent = []

# %%
for i, halo in enumerate(cosmoDC2):
    if halo['healpix'] in bigTable["pixel"]:
        halo["mask"] = 1
    per = int(i/len(cosmoDC2['id'])*100)
    if per in per_list and per not in percent:
        print(per)
        percent.append(per)

# %%
plt.scatter(cosmoDC2['ra'], cosmoDC2['dec'], s = 0.01, label = "CosmoDC2")
plt.scatter(bigTable["ra"], bigTable["dec"], s=0.01, label = "DC2 mask")
plt.xlabel("ra", fontsize = 13)
plt.ylabel("dec", fontsize = 13)
plt.legend()
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /opt/conda/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.scatter(cosmoDC2['ra'], cosmoDC2['dec'], s = 0.01, label = "CosmoDC2")
plt.scatter(cosmoDC2[cosmoDC2['mask']==1]['ra'], cosmoDC2[cosmoDC2['mask']==1]['dec'], s = 0.01, label = "CosmoDC2 halos w mask on")
plt.xlabel("ra", fontsize = 13)
plt.ylabel("dec", fontsize = 13)
plt.legend()
